# %% [markdown]
# # Plot_1

# %% [markdown]
# ### There are ten genres in total in lyrics.csv file. I performed topic modelling on lyrics of each genre and then generated wordclouds to show the frequency of words appear in different topics.

# %%
# %pylab inline
import matplotlib.pyplot as plt
import matplotlib.image as mpimg
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# ##### 1. Pop

# %%
img=mpimg.imread('Pop.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ##### 2. Hip-Hop

# %%
img=mpimg.imread('Hip-Hop.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ##### 3. Rock

# %%
img=mpimg.imread('Rock.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ##### 4. Metal

# %%
img=mpimg.imread('Metal.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ##### 5. Country

# %%
img=mpimg.imread('Country.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ##### 6. JAZZ

# %%
img=mpimg.imread('JAZZ.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ##### 7. Electronic

# %%
img=mpimg.imread('Electronic.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ##### 8. Folk

# %%
img=mpimg.imread('Folk.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ##### 9. R&B

# %%
img=mpimg.imread('R&B.png')
imgplot = plt.imshow(img)
plt.show()

# %% [markdown]
# ##### 10. Indie

# %%
img=mpimg.imread('Indie.png')
imgplot = plt.imshow(img)
plt.show()
